# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline


# Load the CSV files
file_paths = ['../data/opel_corsa_01.csv', '../data/opel_corsa_02.csv',
              '../data/peugeot_207_01.csv', '../data/peugeot_207_02.csv']

# %%
# Load the datasets, specifying semicolon as the delimiter
data_frames = [pd.read_csv(file_path, delimiter=';') for file_path in file_paths]

# %%
# list the columns in the dataset
print(data_frames[0].columns)
# Out:
# Index(['Unnamed: 0', 'AltitudeVariation', 'VehicleSpeedInstantaneous',
#        'VehicleSpeedAverage', 'VehicleSpeedVariance', 'VehicleSpeedVariation',
#        'LongitudinalAcceleration', 'EngineLoad', 'EngineCoolantTemperature',
#        'ManifoldAbsolutePressure', 'EngineRPM', 'MassAirFlow',
#        'IntakeAirTemperature', 'VerticalAcceleration',
#        'FuelConsumptionAverage', 'roadSurface', 'traffic', 'drivingStyle'],
#       dtype='object')

# %%
print(data_frames[0].head())
# Out:
#    Unnamed: 0  AltitudeVariation  VehicleSpeedInstantaneous  \
# 0          59          -2.299988                  25.670519
# 1          60          -2.099976                  24.094259
# 2          61          -1.500000                  22.743179
# 3          62           0.100037                  22.292820
# 4          63           0.099976                  23.643900
#
#    VehicleSpeedAverage  VehicleSpeedVariance  VehicleSpeedVariation  \
# 0            13.223501            121.592690              -2.476980
# 1            13.638919            120.422571              -1.576260
# 2            14.031043            118.456769              -1.351080
# 3            14.171073            117.571308              -0.450359
# 4            14.328954            117.074149               1.351080
#
#    LongitudinalAcceleration  EngineLoad  EngineCoolantTemperature  \
# 0                    0.3555    4.705883                        68
# 1                    0.4492   10.588236                        68
# 2                    0.4258   27.450981                        68
# 3                    0.4140   24.313726                        69
# 4                    0.3945   20.000000                        69
#
#    ManifoldAbsolutePressure  EngineRPM  MassAirFlow  IntakeAirTemperature  \
# 0                       106       1796        15.81                    24
# 1                       103       1689        14.65                    22
# 2                       103       1599        11.85                    21
# 3                       104       1620        12.21                    20
# 4                       104       1708        11.91                    21
#
#    VerticalAcceleration  FuelConsumptionAverage      roadSurface  \
# 0               -0.1133               19.497335  SmoothCondition
# 1               -0.1289               19.515722  SmoothCondition
# 2               -0.1328               19.441765  SmoothCondition
# 3               -0.0859               19.388769  SmoothCondition
# 4               -0.0664               19.301638  SmoothCondition
#
#                   traffic   drivingStyle
# 0  LowCongestionCondition  EvenPaceStyle
# 1  LowCongestionCondition  EvenPaceStyle
# 2  LowCongestionCondition  EvenPaceStyle
# 3  LowCongestionCondition  EvenPaceStyle
# 4  LowCongestionCondition  EvenPaceStyle

# %%
# Combine the datasets
data = pd.concat(data_frames)

# list the columns in the dataset
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'AltitudeVariation', 'VehicleSpeedInstantaneous',
#        'VehicleSpeedAverage', 'VehicleSpeedVariance', 'VehicleSpeedVariation',
#        'LongitudinalAcceleration', 'EngineLoad', 'EngineCoolantTemperature',
#        'ManifoldAbsolutePressure', 'EngineRPM', 'MassAirFlow',
#        'IntakeAirTemperature', 'VerticalAcceleration',
#        'FuelConsumptionAverage', 'roadSurface', 'traffic', 'drivingStyle'],
#       dtype='object')

# %%
# Example: Visualizing the distribution of VehicleSpeedAverage
plt.figure(figsize=(10, 6))
sns.histplot(data['VehicleSpeedAverage'], kde=True, color='blue', bins=30)
plt.title('Distribution of Vehicle Speed Average')
plt.xlabel('Vehicle Speed Average')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Example: Boxplot of EngineLoad by Driving Style
plt.figure(figsize=(10, 6))
sns.boxplot(x='drivingStyle', y='EngineLoad', data=data)
plt.title('Engine Load by Driving Style')
plt.xlabel('Driving Style')
plt.ylabel('Engine Load')
plt.show()

# %%
# Example: Scatter plot of VehicleSpeedAverage vs. FuelConsumptionAverage
plt.figure(figsize=(10, 6))
sns.scatterplot(x='VehicleSpeedAverage', y='FuelConsumptionAverage', data=data, hue='drivingStyle', style='drivingStyle')
plt.title('Vehicle Speed Average vs. Fuel Consumption Average')
plt.xlabel('Vehicle Speed Average')
plt.ylabel('Fuel Consumption Average')
plt.legend(title='Driving Style')
plt.show()

# %%
data
# Out:
#       Unnamed: 0  AltitudeVariation  VehicleSpeedInstantaneous  \
# 0             59          -2.299988                  25.670519
# 1             60          -2.099976                  24.094259
# 2             61          -1.500000                  22.743179
# 3             62           0.100037                  22.292820
# 4             63           0.099976                  23.643900
# ...          ...                ...                        ...
# 4441        4618           1.000000                  28.799999
# 4442        4619           1.699997                  30.599998
# 4443        4620           1.800003                  29.699999
# 4444        4621           2.100006                  29.699999
# 4445        4622           1.500000                  33.299999
#
#       VehicleSpeedAverage  VehicleSpeedVariance  VehicleSpeedVariation  \
# 0               13.223501            121.592690              -2.476980
# 1               13.638919            120.422571              -1.576260
# 2               14.031043            118.456769              -1.351080
# 3               14.171073            117.571308              -0.450359
# 4               14.328954            117.074149               1.351080
# ...                   ...                   ...                    ...
# 4441            28.559999             57.190571               3.600000
# 4442            28.529999             57.010266               1.799999
# 4443            28.499999             56.883045              -0.900000
# 4444            28.409999             56.160910               0.000000
# 4445            28.349999             55.340843               3.600000
#
#       LongitudinalAcceleration  EngineLoad  EngineCoolantTemperature  \
# 0                       0.3555    4.705883                      68.0
# 1                       0.4492   10.588236                      68.0
# 2                       0.4258   27.450981                      68.0
# 3                       0.4140   24.313726                      69.0
# 4                       0.3945   20.000000                      69.0
# ...                        ...         ...                       ...
# 4441                   -0.0292   25.882353                      81.0
# 4442                   -0.0304   11.764706                      81.0
# 4443                   -0.1684   98.039215                      81.0
# 4444                   -0.0644   79.607841                      80.0
# 4445                   -0.1817   80.000000                      80.0
#
#       ManifoldAbsolutePressure  EngineRPM  MassAirFlow  IntakeAirTemperature  \
# 0                        106.0     1796.0    15.810000                  24.0
# 1                        103.0     1689.0    14.650000                  22.0
# 2                        103.0     1599.0    11.850000                  21.0
# 3                        104.0     1620.0    12.210000                  20.0
# 4                        104.0     1708.0    11.910000                  21.0
# ...                        ...        ...          ...                   ...
# 4441                     115.0     1755.5    20.469999                  25.0
# 4442                     106.0      736.5    17.740000                  25.0
# 4443                     106.0     1254.0     9.520000                  24.0
# 4444                     112.0     1254.0    14.910000                  23.0
# 4445                     113.0     1363.5    15.330000                  23.0
#
#       VerticalAcceleration  FuelConsumptionAverage      roadSurface  \
# 0                  -0.1133               19.497335  SmoothCondition
# 1                  -0.1289               19.515722  SmoothCondition
# 2                  -0.1328               19.441765  SmoothCondition
# 3                  -0.0859               19.388769  SmoothCondition
# 4                  -0.0664               19.301638  SmoothCondition
# ...                    ...                     ...              ...
# 4441               -0.1661               14.578003  SmoothCondition
# 4442               -0.1987               14.585642  SmoothCondition
# 4443               -0.1156               14.547294  SmoothCondition
# 4444               -0.0760               14.546828  SmoothCondition
# 4445               -0.0605               14.554068  SmoothCondition
#
#                      traffic   drivingStyle
# 0     LowCongestionCondition  EvenPaceStyle
# 1     LowCongestionCondition  EvenPaceStyle
# 2     LowCongestionCondition  EvenPaceStyle
# 3     LowCongestionCondition  EvenPaceStyle
# 4     LowCongestionCondition  EvenPaceStyle
# ...                      ...            ...
# 4441  LowCongestionCondition  EvenPaceStyle
# 4442  LowCongestionCondition  EvenPaceStyle
# 4443  LowCongestionCondition  EvenPaceStyle
# 4444  LowCongestionCondition  EvenPaceStyle
# 4445  LowCongestionCondition  EvenPaceStyle
#
# [23775 rows x 18 columns]

# %%
# remove the first column of data
data = data.drop('Unnamed: 0', axis=1)

# %%
print(data.head())
# Out:
#    AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# 0          -2.299988                  25.670519            13.223501
# 1          -2.099976                  24.094259            13.638919
# 2          -1.500000                  22.743179            14.031043
# 3           0.100037                  22.292820            14.171073
# 4           0.099976                  23.643900            14.328954
#
#    VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# 0            121.592690              -2.476980                    0.3555
# 1            120.422571              -1.576260                    0.4492
# 2            118.456769              -1.351080                    0.4258
# 3            117.571308              -0.450359                    0.4140
# 4            117.074149               1.351080                    0.3945
#
#    EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  EngineRPM  \
# 0    4.705883                      68.0                     106.0     1796.0
# 1   10.588236                      68.0                     103.0     1689.0
# 2   27.450981                      68.0                     103.0     1599.0
# 3   24.313726                      69.0                     104.0     1620.0
# 4   20.000000                      69.0                     104.0     1708.0
#
#    MassAirFlow  IntakeAirTemperature  VerticalAcceleration  \
# 0        15.81                  24.0               -0.1133
# 1        14.65                  22.0               -0.1289
# 2        11.85                  21.0               -0.1328
# 3        12.21                  20.0               -0.0859
# 4        11.91                  21.0               -0.0664
#
#    FuelConsumptionAverage      roadSurface                 traffic  \
# 0               19.497335  SmoothCondition  LowCongestionCondition
# 1               19.515722  SmoothCondition  LowCongestionCondition
# 2               19.441765  SmoothCondition  LowCongestionCondition
# 3               19.388769  SmoothCondition  LowCongestionCondition
# 4               19.301638  SmoothCondition  LowCongestionCondition
#
#     drivingStyle
# 0  EvenPaceStyle
# 1  EvenPaceStyle
# 2  EvenPaceStyle
# 3  EvenPaceStyle
# 4  EvenPaceStyle

# %%
# print the shape of the data
print(data.shape)
# Out:
# (23775, 17)

# %%
# tail of data
print(data.tail())
# Out:
#       AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# 4441           1.000000                  28.799999            28.559999
# 4442           1.699997                  30.599998            28.529999
# 4443           1.800003                  29.699999            28.499999
# 4444           2.100006                  29.699999            28.409999
# 4445           1.500000                  33.299999            28.349999
#
#       VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# 4441             57.190571               3.600000                   -0.0292
# 4442             57.010266               1.799999                   -0.0304
# 4443             56.883045              -0.900000                   -0.1684
# 4444             56.160910               0.000000                   -0.0644
# 4445             55.340843               3.600000                   -0.1817
#
#       EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 4441   25.882353                      81.0                     115.0
# 4442   11.764706                      81.0                     106.0
# 4443   98.039215                      81.0                     106.0
# 4444   79.607841                      80.0                     112.0
# 4445   80.000000                      80.0                     113.0
#
#       EngineRPM  MassAirFlow  IntakeAirTemperature  VerticalAcceleration  \
# 4441     1755.5    20.469999                  25.0               -0.1661
# 4442      736.5    17.740000                  25.0               -0.1987
# 4443     1254.0     9.520000                  24.0               -0.1156
# 4444     1254.0    14.910000                  23.0               -0.0760
# 4445     1363.5    15.330000                  23.0               -0.0605
#
#       FuelConsumptionAverage      roadSurface                 traffic  \
# 4441               14.578003  SmoothCondition  LowCongestionCondition
# 4442               14.585642  SmoothCondition  LowCongestionCondition
# 4443               14.547294  SmoothCondition  LowCongestionCondition
# 4444               14.546828  SmoothCondition  LowCongestionCondition
# 4445               14.554068  SmoothCondition  LowCongestionCondition
#
#        drivingStyle
# 4441  EvenPaceStyle
# 4442  EvenPaceStyle
# 4443  EvenPaceStyle
# 4444  EvenPaceStyle
# 4445  EvenPaceStyle

# %%
# info of data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23775 entries, 0 to 4445
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   AltitudeVariation          23775 non-null  float64
#  1   VehicleSpeedInstantaneous  23766 non-null  float64
#  2   VehicleSpeedAverage        23775 non-null  float64
#  3   VehicleSpeedVariance       23775 non-null  float64
#  4   VehicleSpeedVariation      23775 non-null  float64
#  5   LongitudinalAcceleration   23775 non-null  float64
#  6   EngineLoad                 23770 non-null  float64
#  7   EngineCoolantTemperature   23770 non-null  float64
#  8   ManifoldAbsolutePressure   23770 non-null  float64
#  9   EngineRPM                  23770 non-null  float64
#  10  MassAirFlow                23770 non-null  float64
#  11  IntakeAirTemperature       23770 non-null  float64
#  12  VerticalAcceleration       23775 non-null  float64
#  13  FuelConsumptionAverage     23770 non-null  float64
#  14  roadSurface                23775 non-null  object
#  15  traffic                    23775 non-null  object
#  16  drivingStyle               23775 non-null  object
# dtypes: float64(14), object(3)
# memory usage: 3.3+ MB
# None

# %%
road_surf_unique = list(data["roadSurface"].unique())
traffic_unique = list(data["traffic"].unique())
drivingStyle_unique = list(data["drivingStyle"].unique())

print(road_surf_unique)
print(traffic_unique)
print(drivingStyle_unique)
# Out:
# ['SmoothCondition', 'UnevenCondition', 'FullOfHolesCondition']
# ['LowCongestionCondition', 'NormalCongestionCondition', 'HighCongestionCondition']
# ['EvenPaceStyle', 'AggressiveStyle']

# %% [markdown]
# First it was needed to handle the missing values in the dataset. The missing values were replaced with the mode of the column.

# %%
print(data.isnull().sum())
# Out:
# AltitudeVariation            0
# VehicleSpeedInstantaneous    9
# VehicleSpeedAverage          0
# VehicleSpeedVariance         0
# VehicleSpeedVariation        0
# LongitudinalAcceleration     0
# EngineLoad                   5
# EngineCoolantTemperature     5
# ManifoldAbsolutePressure     5
# EngineRPM                    5
# MassAirFlow                  5
# IntakeAirTemperature         5
# VerticalAcceleration         0
# FuelConsumptionAverage       5
# roadSurface                  0
# traffic                      0
# drivingStyle                 0
# dtype: int64

# %%
# get columns with missing values
columns_with_missing_values  = data.columns[data.isnull().any()]
print(columns_with_missing_values)
# Out:
# Index(['VehicleSpeedInstantaneous', 'EngineLoad', 'EngineCoolantTemperature',
#        'ManifoldAbsolutePressure', 'EngineRPM', 'MassAirFlow',
#        'IntakeAirTemperature', 'FuelConsumptionAverage'],
#       dtype='object')

# %%
# fill missing values with the mean of the column
data[columns_with_missing_values] = data[columns_with_missing_values].fillna(data[columns_with_missing_values].mean())

# %%
print(data.isnull().sum())
# Out:
# AltitudeVariation            0
# VehicleSpeedInstantaneous    0
# VehicleSpeedAverage          0
# VehicleSpeedVariance         0
# VehicleSpeedVariation        0
# LongitudinalAcceleration     0
# EngineLoad                   0
# EngineCoolantTemperature     0
# ManifoldAbsolutePressure     0
# EngineRPM                    0
# MassAirFlow                  0
# IntakeAirTemperature         0
# VerticalAcceleration         0
# FuelConsumptionAverage       0
# roadSurface                  0
# traffic                      0
# drivingStyle                 0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %% [markdown]
# For the categorical variables (roadSurface, traffic, drivingStyle), needs to convert these into a format that can be used for machine learning models. Since drivingStyle is my target variable, let's focus on roadSurface and traffic.

# %%
data = pd.get_dummies(data, columns=['roadSurface', 'traffic'])

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the encoder
encoder = LabelEncoder()
# Fit and transform the 'drivingStyle' column

data['drivingStyle_encoded'] = encoder.fit_transform(data['drivingStyle'])

# %% [markdown]
# After encoding, lets replace the original drivingStyle column in your DataFrame with the encoded labels or a new one to keep the original for reference

# %%
correlation_matrix = data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 correlation_matrix = data.corr()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'EvenPaceStyle'

# %% [markdown]
# lets drop the non-encoded column

# %%
X = data.drop(['drivingStyle', 'drivingStyle_encoded'], axis=1)  
y = data['drivingStyle_encoded']

# %%
X
# Out:
#       AltitudeVariation  VehicleSpeedInstantaneous  VehicleSpeedAverage  \
# 0             -2.299988                  25.670519            13.223501
# 1             -2.099976                  24.094259            13.638919
# 2             -1.500000                  22.743179            14.031043
# 3              0.100037                  22.292820            14.171073
# 4              0.099976                  23.643900            14.328954
# ...                 ...                        ...                  ...
# 4441           1.000000                  28.799999            28.559999
# 4442           1.699997                  30.599998            28.529999
# 4443           1.800003                  29.699999            28.499999
# 4444           2.100006                  29.699999            28.409999
# 4445           1.500000                  33.299999            28.349999
#
#       VehicleSpeedVariance  VehicleSpeedVariation  LongitudinalAcceleration  \
# 0               121.592690              -2.476980                    0.3555
# 1               120.422571              -1.576260                    0.4492
# 2               118.456769              -1.351080                    0.4258
# 3               117.571308              -0.450359                    0.4140
# 4               117.074149               1.351080                    0.3945
# ...                    ...                    ...                       ...
# 4441             57.190571               3.600000                   -0.0292
# 4442             57.010266               1.799999                   -0.0304
# 4443             56.883045              -0.900000                   -0.1684
# 4444             56.160910               0.000000                   -0.0644
# 4445             55.340843               3.600000                   -0.1817
#
#       EngineLoad  EngineCoolantTemperature  ManifoldAbsolutePressure  \
# 0       4.705883                      68.0                     106.0
# 1      10.588236                      68.0                     103.0
# 2      27.450981                      68.0                     103.0
# 3      24.313726                      69.0                     104.0
# 4      20.000000                      69.0                     104.0
# ...          ...                       ...                       ...
# 4441   25.882353                      81.0                     115.0
# 4442   11.764706                      81.0                     106.0
# 4443   98.039215                      81.0                     106.0
# 4444   79.607841                      80.0                     112.0
# 4445   80.000000                      80.0                     113.0
#
#       EngineRPM  MassAirFlow  IntakeAirTemperature  VerticalAcceleration  \
# 0        1796.0    15.810000                  24.0               -0.1133
# 1        1689.0    14.650000                  22.0               -0.1289
# 2        1599.0    11.850000                  21.0               -0.1328
# 3        1620.0    12.210000                  20.0               -0.0859
# 4        1708.0    11.910000                  21.0               -0.0664
# ...         ...          ...                   ...                   ...
# 4441     1755.5    20.469999                  25.0               -0.1661
# 4442      736.5    17.740000                  25.0               -0.1987
# 4443     1254.0     9.520000                  24.0               -0.1156
# 4444     1254.0    14.910000                  23.0               -0.0760
# 4445     1363.5    15.330000                  23.0               -0.0605
#
#       FuelConsumptionAverage  roadSurface_FullOfHolesCondition  \
# 0                  19.497335                             False
# 1                  19.515722                             False
# 2                  19.441765                             False
# 3                  19.388769                             False
# 4                  19.301638                             False
# ...                      ...                               ...
# 4441               14.578003                             False
# 4442               14.585642                             False
# 4443               14.547294                             False
# 4444               14.546828                             False
# 4445               14.554068                             False
#
#       roadSurface_SmoothCondition  roadSurface_UnevenCondition  \
# 0                            True                        False
# 1                            True                        False
# 2                            True                        False
# 3                            True                        False
# 4                            True                        False
# ...                           ...                          ...
# 4441                         True                        False
# 4442                         True                        False
# 4443                         True                        False
# 4444                         True                        False
# 4445                         True                        False
#
#       traffic_HighCongestionCondition  traffic_LowCongestionCondition  \
# 0                               False                            True
# 1                               False                            True
# 2                               False                            True
# 3                               False                            True
# 4                               False                            True
# ...                               ...                             ...
# 4441                            False                            True
# 4442                            False                            True
# 4443                            False                            True
# 4444                            False                            True
# 4445                            False                            True
#
#       traffic_NormalCongestionCondition
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 4441                              False
# 4442                              False
# 4443                              False
# 4444                              False
# 4445                              False
#
# [23775 rows x 20 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4441    1
# 4442    1
# 4443    1
# 4444    1
# 4445    1
# Name: drivingStyle_encoded, Length: 23775, dtype: int32

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=377123)

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# Now will use pandas to produce a heatmap and try find correlations between the features

# %%
import pandas as pd

X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)

# %%
X_train_scaled_df['drivingStyle_encoded'] = y_train.values

# %%
correlation_matrix = X_train_scaled_df.corr()

# %%
print(correlation_matrix)
# Out:
#                                    AltitudeVariation  \
# AltitudeVariation                           1.000000
# VehicleSpeedInstantaneous                   0.025559
# VehicleSpeedAverage                         0.048763
# VehicleSpeedVariance                       -0.103089
# VehicleSpeedVariation                      -0.011467
# LongitudinalAcceleration                    0.082784
# EngineLoad                                  0.139895
# EngineCoolantTemperature                   -0.006027
# ManifoldAbsolutePressure                    0.098960
# EngineRPM                                  -0.015290
# MassAirFlow                                 0.033780
# IntakeAirTemperature                        0.097342
# VerticalAcceleration                        0.122780
# FuelConsumptionAverage                      0.004101
# roadSurface_FullOfHolesCondition            0.014590
# roadSurface_SmoothCondition                -0.010735
# roadSurface_UnevenCondition                 0.000525
# traffic_HighCongestionCondition             0.025057
# traffic_LowCongestionCondition             -0.045469
# traffic_NormalCongestionCondition           0.034435
# drivingStyle_encoded                        0.048000
#
#                                    VehicleSpeedInstantaneous  \
# AltitudeVariation                                   0.025559
# VehicleSpeedInstantaneous                           1.000000
# VehicleSpeedAverage                                 0.867254
# VehicleSpeedVariance                               -0.051472
# VehicleSpeedVariation                               0.037666
# LongitudinalAcceleration                            0.038157
# EngineLoad                                          0.276356
# EngineCoolantTemperature                            0.235816
# ManifoldAbsolutePressure                            0.719838
# EngineRPM                                           0.839208
# MassAirFlow                                         0.815829
# IntakeAirTemperature                                0.346188
# VerticalAcceleration                                0.065959
# FuelConsumptionAverage                             -0.476362
# roadSurface_FullOfHolesCondition                   -0.125085
# roadSurface_SmoothCondition                         0.332499
# roadSurface_UnevenCondition                        -0.272024
# traffic_HighCongestionCondition                    -0.307879
# traffic_LowCongestionCondition                      0.314471
# traffic_NormalCongestionCondition                  -0.102642
# drivingStyle_encoded                                0.140569
#
#                                    VehicleSpeedAverage  VehicleSpeedVariance  \
# AltitudeVariation                             0.048763             -0.103089
# VehicleSpeedInstantaneous                     0.867254             -0.051472
# VehicleSpeedAverage                           1.000000             -0.034165
# VehicleSpeedVariance                         -0.034165              1.000000
# VehicleSpeedVariation                        -0.077807              0.037714
# LongitudinalAcceleration                      0.171685             -0.016447
# EngineLoad                                    0.259732             -0.084488
# EngineCoolantTemperature                      0.294733              0.070034
# ManifoldAbsolutePressure                      0.607855              0.002312
# EngineRPM                                     0.650551             -0.002122
# MassAirFlow                                   0.638681              0.011279
# IntakeAirTemperature                          0.347394             -0.110992
# VerticalAcceleration                          0.033549             -0.007725
# FuelConsumptionAverage                       -0.614882             -0.109880
# roadSurface_FullOfHolesCondition             -0.139085             -0.043139
# roadSurface_SmoothCondition                   0.362242              0.105441
# roadSurface_UnevenCondition                  -0.294157             -0.083546
# traffic_HighCongestionCondition              -0.325281             -0.152595
# traffic_LowCongestionCondition                0.332319              0.065230
# traffic_NormalCongestionCondition            -0.108539              0.068058
# drivingStyle_encoded                          0.101597             -0.137158
#
#                                    VehicleSpeedVariation  \
# AltitudeVariation                              -0.011467
# VehicleSpeedInstantaneous                       0.037666
# VehicleSpeedAverage                            -0.077807
# VehicleSpeedVariance                            0.037714
# VehicleSpeedVariation                           1.000000
# LongitudinalAcceleration                       -0.108335
# EngineLoad                                      0.274704
# EngineCoolantTemperature                       -0.028872
# ManifoldAbsolutePressure                        0.250498
# EngineRPM                                       0.239662
# MassAirFlow                                     0.259282
# IntakeAirTemperature                            0.052480
# VerticalAcceleration                            0.028384
# FuelConsumptionAverage                          0.055289
# roadSurface_FullOfHolesCondition                0.009026
# roadSurface_SmoothCondition                    -0.002319
# roadSurface_UnevenCondition                    -0.004484
# traffic_HighCongestionCondition                 0.000751
# traffic_LowCongestionCondition                 -0.003864
# traffic_NormalCongestionCondition               0.004315
# drivingStyle_encoded                           -0.014050
#
#                                    LongitudinalAcceleration  EngineLoad  \
# AltitudeVariation                                  0.082784    0.139895
# VehicleSpeedInstantaneous                          0.038157    0.276356
# VehicleSpeedAverage                                0.171685    0.259732
# VehicleSpeedVariance                              -0.016447   -0.084488
# VehicleSpeedVariation                             -0.108335    0.274704
# LongitudinalAcceleration                           1.000000   -0.007279
# EngineLoad                                        -0.007279    1.000000
# EngineCoolantTemperature                           0.053740   -0.071849
# ManifoldAbsolutePressure                           0.015764    0.461102
# EngineRPM                                         -0.025289    0.221672
# MassAirFlow                                       -0.021003    0.324920
# IntakeAirTemperature                               0.134933    0.320377
# VerticalAcceleration                               0.747906   -0.007141
# FuelConsumptionAverage                            -0.058930   -0.110381
# roadSurface_FullOfHolesCondition                  -0.058740    0.053547
# roadSurface_SmoothCondition                        0.051368   -0.006364
# roadSurface_UnevenCondition                       -0.011178   -0.034826
# traffic_HighCongestionCondition                   -0.073068   -0.018703
# traffic_LowCongestionCondition                     0.074716   -0.005400
# traffic_NormalCongestionCondition                 -0.024470    0.025919
# drivingStyle_encoded                              -0.033600    0.080433
#
#                                    EngineCoolantTemperature  \
# AltitudeVariation                                 -0.006027
# VehicleSpeedInstantaneous                          0.235816
# VehicleSpeedAverage                                0.294733
# VehicleSpeedVariance                               0.070034
# VehicleSpeedVariation                             -0.028872
# LongitudinalAcceleration                           0.053740
# EngineLoad                                        -0.071849
# EngineCoolantTemperature                           1.000000
# ManifoldAbsolutePressure                           0.254417
# EngineRPM                                          0.243243
# MassAirFlow                                        0.172477
# IntakeAirTemperature                               0.298207
# VerticalAcceleration                              -0.000650
# FuelConsumptionAverage                            -0.444686
# roadSurface_FullOfHolesCondition                  -0.543214
# roadSurface_SmoothCondition                        0.385689
# roadSurface_UnevenCondition                       -0.003967
# traffic_HighCongestionCondition                   -0.128482
# traffic_LowCongestionCondition                     0.207247
# traffic_NormalCongestionCondition                 -0.142583
# drivingStyle_encoded                              -0.053618
#
#                                    ManifoldAbsolutePressure  EngineRPM  ...  \
# AltitudeVariation                                  0.098960  -0.015290  ...
# VehicleSpeedInstantaneous                          0.719838   0.839208  ...
# VehicleSpeedAverage                                0.607855   0.650551  ...
# VehicleSpeedVariance                               0.002312  -0.002122  ...
# VehicleSpeedVariation                              0.250498   0.239662  ...
# LongitudinalAcceleration                           0.015764  -0.025289  ...
# EngineLoad                                         0.461102   0.221672  ...
# EngineCoolantTemperature                           0.254417   0.243243  ...
# ManifoldAbsolutePressure                           1.000000   0.711176  ...
# EngineRPM                                          0.711176   1.000000  ...
# MassAirFlow                                        0.871528   0.875482  ...
# IntakeAirTemperature                               0.199100   0.250048  ...
# VerticalAcceleration                               0.144229   0.116142  ...
# FuelConsumptionAverage                            -0.270956  -0.313905  ...
# roadSurface_FullOfHolesCondition                  -0.167104  -0.176090  ...
# roadSurface_SmoothCondition                        0.363656   0.405729  ...
# roadSurface_UnevenCondition                       -0.273803  -0.313577  ...
# traffic_HighCongestionCondition                   -0.224636  -0.333836  ...
# traffic_LowCongestionCondition                     0.277254   0.359309  ...
# traffic_NormalCongestionCondition                 -0.137625  -0.135343  ...
# drivingStyle_encoded                               0.004515   0.010699  ...
#
#                                    IntakeAirTemperature  VerticalAcceleration  \
# AltitudeVariation                              0.097342              0.122780
# VehicleSpeedInstantaneous                      0.346188              0.065959
# VehicleSpeedAverage                            0.347394              0.033549
# VehicleSpeedVariance                          -0.110992             -0.007725
# VehicleSpeedVariation                          0.052480              0.028384
# LongitudinalAcceleration                       0.134933              0.747906
# EngineLoad                                     0.320377             -0.007141
# EngineCoolantTemperature                       0.298207             -0.000650
# ManifoldAbsolutePressure                       0.199100              0.144229
# EngineRPM                                      0.250048              0.116142
# MassAirFlow                                    0.207664              0.108314
# IntakeAirTemperature                           1.000000             -0.171168
# VerticalAcceleration                          -0.171168              1.000000
# FuelConsumptionAverage                        -0.411259              0.186889
# roadSurface_FullOfHolesCondition              -0.181288             -0.096146
# roadSurface_SmoothCondition                   -0.078897              0.163308
# roadSurface_UnevenCondition                    0.229653             -0.106441
# traffic_HighCongestionCondition               -0.012767             -0.016537
# traffic_LowCongestionCondition                 0.000301              0.027247
# traffic_NormalCongestionCondition              0.012461             -0.019102
# drivingStyle_encoded                           0.120661             -0.076948
#
#                                    FuelConsumptionAverage  \
# AltitudeVariation                                0.004101
# VehicleSpeedInstantaneous                       -0.476362
# VehicleSpeedAverage                             -0.614882
# VehicleSpeedVariance                            -0.109880
# VehicleSpeedVariation                            0.055289
# LongitudinalAcceleration                        -0.058930
# EngineLoad                                      -0.110381
# EngineCoolantTemperature                        -0.444686
# ManifoldAbsolutePressure                        -0.270956
# EngineRPM                                       -0.313905
# MassAirFlow                                     -0.292861
# IntakeAirTemperature                            -0.411259
# VerticalAcceleration                             0.186889
# FuelConsumptionAverage                           1.000000
# roadSurface_FullOfHolesCondition                 0.057143
# roadSurface_SmoothCondition                     -0.068193
# roadSurface_UnevenCondition                      0.031146
# traffic_HighCongestionCondition                  0.252889
# traffic_LowCongestionCondition                  -0.226518
# traffic_NormalCongestionCondition                0.042598
# drivingStyle_encoded                            -0.068939
#
#                                    roadSurface_FullOfHolesCondition  \
# AltitudeVariation                                          0.014590
# VehicleSpeedInstantaneous                                 -0.125085
# VehicleSpeedAverage                                       -0.139085
# VehicleSpeedVariance                                      -0.043139
# VehicleSpeedVariation                                      0.009026
# LongitudinalAcceleration                                  -0.058740
# EngineLoad                                                 0.053547
# EngineCoolantTemperature                                  -0.543214
# ManifoldAbsolutePressure                                  -0.167104
# EngineRPM                                                 -0.176090
# MassAirFlow                                               -0.105496
# IntakeAirTemperature                                      -0.181288
# VerticalAcceleration                                      -0.096146
# FuelConsumptionAverage                                     0.057143
# roadSurface_FullOfHolesCondition                           1.000000
# roadSurface_SmoothCondition                               -0.488245
# roadSurface_UnevenCondition                               -0.239423
# traffic_HighCongestionCondition                            0.093672
# traffic_LowCongestionCondition                             0.015619
# traffic_NormalCongestionCondition                         -0.114819
# drivingStyle_encoded                                       0.082352
#
#                                    roadSurface_SmoothCondition  \
# AltitudeVariation                                    -0.010735
# VehicleSpeedInstantaneous                             0.332499
# VehicleSpeedAverage                                   0.362242
# VehicleSpeedVariance                                  0.105441
# VehicleSpeedVariation                                -0.002319
# LongitudinalAcceleration                              0.051368
# EngineLoad                                           -0.006364
# EngineCoolantTemperature                              0.385689
# ManifoldAbsolutePressure                              0.363656
# EngineRPM                                             0.405729
# MassAirFlow                                           0.323250
# IntakeAirTemperature                                 -0.078897
# VerticalAcceleration                                  0.163308
# FuelConsumptionAverage                               -0.068193
# roadSurface_FullOfHolesCondition                     -0.488245
# roadSurface_SmoothCondition                           1.000000
# roadSurface_UnevenCondition                          -0.730428
# traffic_HighCongestionCondition                      -0.263440
# traffic_LowCongestionCondition                        0.402741
# traffic_NormalCongestionCondition                    -0.263220
# drivingStyle_encoded                                 -0.150381
#
#                                    roadSurface_UnevenCondition  \
# AltitudeVariation                                     0.000525
# VehicleSpeedInstantaneous                            -0.272024
# VehicleSpeedAverage                                  -0.294157
# VehicleSpeedVariance                                 -0.083546
# VehicleSpeedVariation                                -0.004484
# LongitudinalAcceleration                             -0.011178
# EngineLoad                                           -0.034826
# EngineCoolantTemperature                             -0.003967
# ManifoldAbsolutePressure                             -0.273803
# EngineRPM                                            -0.313577
# MassAirFlow                                          -0.277064
# IntakeAirTemperature                                  0.229653
# VerticalAcceleration                                 -0.106441
# FuelConsumptionAverage                                0.031146
# roadSurface_FullOfHolesCondition                     -0.239423
# roadSurface_SmoothCondition                          -0.730428
# roadSurface_UnevenCondition                           1.000000
# traffic_HighCongestionCondition                       0.219777
# traffic_LowCongestionCondition                       -0.460287
# traffic_NormalCongestionCondition                     0.382700
# drivingStyle_encoded                                  0.102854
#
#                                    traffic_HighCongestionCondition  \
# AltitudeVariation                                         0.025057
# VehicleSpeedInstantaneous                                -0.307879
# VehicleSpeedAverage                                      -0.325281
# VehicleSpeedVariance                                     -0.152595
# VehicleSpeedVariation                                     0.000751
# LongitudinalAcceleration                                 -0.073068
# EngineLoad                                               -0.018703
# EngineCoolantTemperature                                 -0.128482
# ManifoldAbsolutePressure                                 -0.224636
# EngineRPM                                                -0.333836
# MassAirFlow                                              -0.298484
# IntakeAirTemperature                                     -0.012767
# VerticalAcceleration                                     -0.016537
# FuelConsumptionAverage                                    0.252889
# roadSurface_FullOfHolesCondition                          0.093672
# roadSurface_SmoothCondition                              -0.263440
# roadSurface_UnevenCondition                               0.219777
# traffic_HighCongestionCondition                           1.000000
# traffic_LowCongestionCondition                           -0.656866
# traffic_NormalCongestionCondition                        -0.144985
# drivingStyle_encoded                                      0.065547
#
#                                    traffic_LowCongestionCondition  \
# AltitudeVariation                                       -0.045469
# VehicleSpeedInstantaneous                                0.314471
# VehicleSpeedAverage                                      0.332319
# VehicleSpeedVariance                                     0.065230
# VehicleSpeedVariation                                   -0.003864
# LongitudinalAcceleration                                 0.074716
# EngineLoad                                              -0.005400
# EngineCoolantTemperature                                 0.207247
# ManifoldAbsolutePressure                                 0.277254
# EngineRPM                                                0.359309
# MassAirFlow                                              0.319655
# IntakeAirTemperature                                     0.000301
# VerticalAcceleration                                     0.027247
# FuelConsumptionAverage                                  -0.226518
# roadSurface_FullOfHolesCondition                         0.015619
# roadSurface_SmoothCondition                              0.402741
# roadSurface_UnevenCondition                             -0.460287
# traffic_HighCongestionCondition                         -0.656866
# traffic_LowCongestionCondition                           1.000000
# traffic_NormalCongestionCondition                       -0.650805
# drivingStyle_encoded                                    -0.073241
#
#                                    traffic_NormalCongestionCondition  \
# AltitudeVariation                                           0.034435
# VehicleSpeedInstantaneous                                  -0.102642
# VehicleSpeedAverage                                        -0.108539
# VehicleSpeedVariance                                        0.068058
# VehicleSpeedVariation                                       0.004315
# LongitudinalAcceleration                                   -0.024470
# EngineLoad                                                  0.025919
# EngineCoolantTemperature                                   -0.142583
# ManifoldAbsolutePressure                                   -0.137625
# EngineRPM                                                  -0.135343
# MassAirFlow                                                -0.118905
# IntakeAirTemperature                                        0.012461
# VerticalAcceleration                                       -0.019102
# FuelConsumptionAverage                                      0.042598
# roadSurface_FullOfHolesCondition                           -0.114819
# roadSurface_SmoothCondition                                -0.263220
# roadSurface_UnevenCondition                                 0.382700
# traffic_HighCongestionCondition                            -0.144985
# traffic_LowCongestionCondition                             -0.650805
# traffic_NormalCongestionCondition                           1.000000
# drivingStyle_encoded                                        0.030107
#
#                                    drivingStyle_encoded
# AltitudeVariation                              0.048000
# VehicleSpeedInstantaneous                      0.140569
# VehicleSpeedAverage                            0.101597
# VehicleSpeedVariance                          -0.137158
# VehicleSpeedVariation                         -0.014050
# LongitudinalAcceleration                      -0.033600
# EngineLoad                                     0.080433
# EngineCoolantTemperature                      -0.053618
# ManifoldAbsolutePressure                       0.004515
# EngineRPM                                      0.010699
# MassAirFlow                                    0.017707
# IntakeAirTemperature                           0.120661
# VerticalAcceleration                          -0.076948
# FuelConsumptionAverage                        -0.068939
# roadSurface_FullOfHolesCondition               0.082352
# roadSurface_SmoothCondition                   -0.150381
# roadSurface_UnevenCondition                    0.102854
# traffic_HighCongestionCondition                0.065547
# traffic_LowCongestionCondition                -0.073241
# traffic_NormalCongestionCondition              0.030107
# drivingStyle_encoded                           1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Matrix of Features and Driving Style")
plt.show()

# %%
X_train_scaled
# Out:
# array([[ 0.50199754,  0.39941414, -0.29212396, ..., -0.38253834,
#          0.58236904, -0.37900845],
#        [ 2.88954355,  1.52338594,  1.66229643, ..., -0.38253834,
#          0.58236904, -0.37900845],
#        [-0.21426407,  1.99194948,  2.27381256, ..., -0.38253834,
#          0.58236904, -0.37900845],
#        ...,
#        [ 0.02449344, -0.74033438, -0.78216458, ...,  2.61411704,
#         -1.71712425, -0.37900845],
#        [-1.07377219,  0.03199368,  0.020271  , ..., -0.38253834,
#          0.58236904, -0.37900845],
#        [ 0.21547542, -0.77333146, -0.6708453 , ..., -0.38253834,
#          0.58236904, -0.37900845]])

# %% [markdown]
# GridSearchCV

# %% [markdown]
# For each classifier, I will define the parameter grid. For SVM different kernels. For Logistic Regression and KNN, will vary regularization and the number of neighbors.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd

# %%
Cs = [0.001, 0.01, 0.1, 1, 2, 5, 10]
kernels = ['linear', 'poly', 'rbf', 'sigmoid']

# %%
# Parameters for grid search
svc_class = SVC(kernel='linear')
svm_params = {"C": Cs, "kernel": kernels}
Cs, kernels
# Out:
# ([0.001, 0.01, 0.1, 1, 2, 5, 10], ['linear', 'poly', 'rbf', 'sigmoid'])

# %%
svm_grid = GridSearchCV(svc_class, param_grid= svm_params, cv=5, verbose=2)

# %%
svm_grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [CV] END .............................C=0.001, kernel=linear; total time=   1.2s
# [CV] END .............................C=0.001, kernel=linear; total time=   1.2s
# [CV] END .............................C=0.001, kernel=linear; total time=   1.3s
# [CV] END .............................C=0.001, kernel=linear; total time=   1.3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 svm_grid.fit(X_train_scaled,y_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
svm_grid.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
svm_grid.best_score_
# Out:
# 0.9131440588853839

# %%
svm_grid.best_estimator_.score(X_test_scaled, y_test)
# Out:
# 0.9154574132492114

# %%
from sklearn.metrics import classification_report

# Use the best estimator from the grid search to make predictions on the test set
svm_best = svm_grid.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 4
#       1 from sklearn.metrics import classification_report
#       3 # Use the best estimator from the grid search to make predictions on the test set
# ----> 4 svm_best = svm_grid.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
y_pred_svm = svm_best.predict(X_test)
# Out:
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
encoder_classes = encoder.classes_
encoder_classes
# Out:
# array(['AggressiveStyle', 'EvenPaceStyle'], dtype=object)

# %%
class_labels = [str(cls) for cls in encoder.classes_]

# %%
encoder_classes
# Out:
# array(['AggressiveStyle', 'EvenPaceStyle'], dtype=object)

# %%
# Evaluation metrics
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

print(classification_report(y_test, y_pred_svm, target_names=class_labels))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svm))
# Out:
#                  precision    recall  f1-score   support
#
# AggressiveStyle       0.00      0.00      0.00       547
#   EvenPaceStyle       0.88      1.00      0.94      4208
#
#        accuracy                           0.88      4755
#       macro avg       0.44      0.50      0.47      4755
#    weighted avg       0.78      0.88      0.83      4755
#
# Confusion Matrix:
#  [[   0  547]
#  [   0 4208]]
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
label_mapping = dict(zip(encoder.classes_, range(len(encoder.classes_))))
print(label_mapping)
# Out:
# {'AggressiveStyle': 0, 'EvenPaceStyle': 1}

# %%
# Fit PCA on scaled data
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train_scaled)

# %%
# Get the absolute values of the contribution of each feature
components_abs = np.abs(pca.components_)

# %%
# Get the feature names
feature_names = list(X.columns)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_pca, y_train)
# Out:
# LogisticRegression()

# %%
X_test_scaled = scaler.transform(X_test)  # Scale test data
X_test_pca = pca.transform(X_test_scaled)  # Apply PCA transformation to test data

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions
y_pred = model.predict(X_test_pca)

# Evaluate model
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8849631966351209
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       547
#            1       0.88      1.00      0.94      4208
#
#     accuracy                           0.88      4755
#    macro avg       0.44      0.50      0.47      4755
# weighted avg       0.78      0.88      0.83      4755
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rodri\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Plotting the feature importances for the first two principal components
plt.figure(figsize=(12, 6))

# Plot for the first principal component
plt.subplot(1, 2, 1)
plt.barh(feature_names, components_abs[0])
plt.title('Principal Component 1')

# Plot for the second principal component
plt.subplot(1, 2, 2)
plt.barh(feature_names, components_abs[1])
plt.title('Principal Component 2')

plt.tight_layout()
plt.show()

# %%
# For each principal component, identify the feature with the highest contribution
top_features = [feature_names[components_abs[i].argmax()] for i in range(components_abs.shape[0])]

# %%
# Create labels for the plot based on the top features
labels = [f"PC1: {top_features[0]}", f"PC2: {top_features[1]}"]

# %%
# Create a DataFrame for the PCA results
pca_df = pd.DataFrame(data=X_pca, columns=labels)
pca_df['DrivingStyle'] = y_train.values

# %%
# Assuming pca_df['DrivingStyle'] currently contains numeric labels
pca_df['DrivingStyle'] = pca_df['DrivingStyle'].map({0: 'AggressiveStyle', 1: 'EvenPaceStyle'})

# %%
# Assuming the labels for PCA components are stored in `labels`
plt.figure(figsize=(10, 8))
sns.scatterplot(x=labels[0], y=labels[1], hue='DrivingStyle', data=pca_df, palette='viridis', alpha=0.7)
plt.title('PCA of Driving Styles with Influential Features')
plt.xlabel(labels[0])
plt.ylabel(labels[1])
plt.legend(title='Driving Style', loc='best')
plt.show()

# %% [markdown]
# Usine SMOTE to balance the data using x and y before PCA. SMOTE to oversample the minority class in the training data

# %%
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(random_state=377123)

# Fit SMOTE to the training data
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

# Check the class distribution after applying SMOTE
from collections import Counter
print(f"Original class distribution: {Counter(y_train)}")
print(f"Resampled class distribution: {Counter(y_train_smote)}")
# Out:
# Original class distribution: Counter({1: 16808, 0: 2212})
# Resampled class distribution: Counter({1: 16808, 0: 16808})

# %% [markdown]
# Re-run GridSearchCV with the Balanced Training Data

# %%
svm_grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 svm_grid.fit(X_train_smote, y_train_smote)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
svm_grid.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
svm_grid.best_score_
# Out:
# 0.9117684698739434

# %%
# Predicting on the scaled test data
y_pred_svm = svm_grid.best_estimator_.predict(X_test_scaled)

# %%
# Evaluation
print(classification_report(y_test, y_pred_svm, target_names=encoder.classes_))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svm))
# Out:
#                  precision    recall  f1-score   support
#
# AggressiveStyle       0.43      0.84      0.57       547
#   EvenPaceStyle       0.98      0.86      0.91      4208
#
#        accuracy                           0.85      4755
#       macro avg       0.70      0.85      0.74      4755
#    weighted avg       0.91      0.85      0.87      4755
#
# Confusion Matrix:
#  [[ 458   89]
#  [ 606 3602]]

# %%
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred_svm)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_, vmin=0, vmax=conf_matrix.max() )
plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 import seaborn as sns
# ----> 3 conf_matrix = confusion_matrix(y_test, y_pred_svm)
#       5 plt.figure(figsize=(8, 6))
#       6 sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_, vmin=0, vmax=conf_matrix.max() )
#
# NameError: name 'y_pred_svm' is not defined

# %% [markdown]
# Logistic Regression

# %%
#logistic regression
log_reg_params = {'C': [0.01, 0.1, 1, 10, 100, 1000]}

# %%
log_reg_grid = GridSearchCV(LogisticRegression(max_iter=10000), log_reg_params, cv=5, verbose=2, scoring='accuracy')

# %%
log_reg_grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .............................................C=0.01; total time=   0.0s
# [CV] END .............................................C=0.01; total time=   0.0s
# [CV] END .............................................C=0.01; total time=   0.0s
# [CV] END .............................................C=0.01; total time=   0.0s
# [CV] END .............................................C=0.01; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ..............................................C=0.1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ................................................C=1; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ...............................................C=10; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END ..............................................C=100; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# [CV] END .............................................C=1000; total time=   0.0s
# GridSearchCV(cv=5, estimator=LogisticRegression(max_iter=10000),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              scoring='accuracy', verbose=2)

# %%
# Print the best parameters and the best score
print("Best parameters:", log_reg_grid.best_params_)
print("Best score:", log_reg_grid.best_score_)
# Out:
# Best parameters: {'C': 0.1}
# Best score: 0.731556419345171

# %%
y_pred_log_reg = log_reg_grid.best_estimator_.predict(X_test_scaled)

# %%
# Assuming 'encoder.classes_' holds the names of your classes
print("Classification Report for Logistic Regression:")
print(classification_report(y_test, y_pred_log_reg, target_names=encoder.classes_))

print("Confusion Matrix for Logistic Regression:\n", confusion_matrix(y_test, y_pred_log_reg))
# Out:
# Classification Report for Logistic Regression:
#                  precision    recall  f1-score   support
#
# AggressiveStyle       0.24      0.73      0.36       547
#   EvenPaceStyle       0.95      0.69      0.80      4208
#
#        accuracy                           0.70      4755
#       macro avg       0.59      0.71      0.58      4755
#    weighted avg       0.87      0.70      0.75      4755
#
# Confusion Matrix for Logistic Regression:
#  [[ 398  149]
#  [1284 2924]]

# %%
import seaborn as sns

conf_matrix = confusion_matrix(y_test, y_pred_log_reg)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support

# Calculate metrics
precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred_log_reg, average=None)
categories = ['Class 0', 'Class 1']

# Plotting
fig, ax = plt.subplots(1, 3, figsize=(18, 5))

# Precision
ax[0].bar(categories, precision)
ax[0].set_title('Precision')
ax[0].set_ylim([0, 1])

# Recall
ax[1].bar(categories, recall)
ax[1].set_title('Recall')
ax[1].set_ylim([0, 1])

# F1-Score
ax[2].bar(categories, f1)
ax[2].set_title('F1-Score')
ax[2].set_ylim([0, 1])

plt.suptitle('Logistic Regression Performance Metrics')
plt.show()

# %%
# Assuming Logistic Regression model
feature_importances = pd.Series(log_reg_grid.best_estimator_.coef_[0], index=X.columns)

plt.figure(figsize=(8, 6))
feature_importances.nlargest(10).plot(kind='barh')
plt.title('Top 10 Feature Importances')
plt.show()

# %%
import pandas as pd

# Convert numpy array to pandas Series
y_series = pd.Series(y_train_smote)

# Count instances for each class
class_distribution = y_series.value_counts()

# If you've encoded the classes and want to show the original names
class_distribution.index = encoder.inverse_transform(class_distribution.index.astype(int))

print(class_distribution)
# Out:
# EvenPaceStyle      16808
# AggressiveStyle    16808
# Name: count, dtype: int64

# %%
# Fit PCA on scaled data
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_train_smote)

# %%
# Get the absolute values of the contribution of each feature
components_abs = np.abs(pca.components_)

# %%
# Get the feature names
feature_names = list(X.columns)

# %%
# For each principal component, identify the feature with the highest contribution
top_features = [feature_names[components_abs[i].argmax()] for i in range(components_abs.shape[0])]

# %%
# Create labels for the plot based on the top features
labels = [f"PC1: {top_features[0]}", f"PC2: {top_features[1]}"]

# %%
# Create a DataFrame for the PCA results

pca_df = pd.DataFrame(data=X_pca, columns=labels)
pca_df['DrivingStyle'] = y_train_smote.values

# %%
# Assuming pca_df['DrivingStyle'] currently contains numeric labels
pca_df['DrivingStyle'] = pca_df['DrivingStyle'].map({0: 'AggressiveStyle', 1: 'EvenPaceStyle'})

# %%
# Assuming the labels for PCA components are stored in `labels`
plt.figure(figsize=(10, 8))
sns.scatterplot(x=labels[0], y=labels[1], hue='DrivingStyle', data=pca_df, palette='viridis', alpha=0.7)
plt.title('PCA of Driving Styles with Influential Features with balanced data')
plt.xlabel(labels[0])
plt.ylabel(labels[1])
plt.legend(title='Driving Style', loc='best')
plt.show()

# %% [markdown]
# K-Nearest Neighbors Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Initialize the kNN model
knn = KNeighborsClassifier()

# %%
# KNN
knn_params = {'n_neighbors': [3, 5, 7, 9, 11]}

# %%
#import gridsearch
from sklearn.model_selection import GridSearchCV

knn_grid = GridSearchCV(knn, knn_params, cv=5, scoring='accuracy', verbose=2)

# %%
knn_grid.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=3; total time=   0.1s
# [CV] END ......................................n_neighbors=5; total time=   0.1s
# [CV] END ......................................n_neighbors=5; total time=   0.1s
# [CV] END ......................................n_neighbors=5; total time=   0.1s
# [CV] END ......................................n_neighbors=5; total time=   0.1s
# [CV] END ......................................n_neighbors=5; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=9; total time=   0.1s
# [CV] END ......................................n_neighbors=9; total time=   0.1s
# [CV] END ......................................n_neighbors=9; total time=   0.1s
# [CV] END ......................................n_neighbors=9; total time=   0.1s
# [CV] END ......................................n_neighbors=9; total time=   0.1s
# [CV] END .....................................n_neighbors=11; total time=   0.1s
# [CV] END .....................................n_neighbors=11; total time=   0.1s
# [CV] END .....................................n_neighbors=11; total time=   0.1s
# [CV] END .....................................n_neighbors=11; total time=   0.1s
# [CV] END .....................................n_neighbors=11; total time=   0.1s
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9, 11]}, scoring='accuracy',
#              verbose=2)

# %%
# Print the best parameters and the best score
print("Best parameters:", knn_grid.best_params_)
print("Best score:", knn_grid.best_score_)
# Out:
# Best parameters: {'n_neighbors': 3}
# Best score: 0.9502319543226777

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# Classification Report and confusion matrix
y_pred_knn = knn_grid.best_estimator_.predict(X_test_scaled)

print("Classification Report for kNN:")
print(classification_report(y_test, y_pred_knn, target_names=encoder.classes_))

print("Confusion Matrix for kNN:\n", confusion_matrix(y_test, y_pred_knn))
# Out:
# Classification Report for kNN:
#                  precision    recall  f1-score   support
#
# AggressiveStyle       0.59      0.84      0.69       547
#   EvenPaceStyle       0.98      0.92      0.95      4208
#
#        accuracy                           0.91      4755
#       macro avg       0.78      0.88      0.82      4755
#    weighted avg       0.93      0.91      0.92      4755
#
# Confusion Matrix for kNN:
#  [[ 458   89]
#  [ 320 3888]]

# %%
conf_matrix = confusion_matrix(y_test, y_pred_knn)

# Plot confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.model_selection import KFold
mean_train_scores = train_scores.mean(axis=1)
mean_valid_scores = valid_scores.mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 from sklearn.model_selection import KFold
# ----> 2 mean_train_scores = train_scores.mean(axis=1)
#       3 mean_valid_scores = valid_scores.mean(axis=1)
#
# NameError: name 'train_scores' is not defined

# %% [markdown]
# Overall comparison

# %%
print("Best SVM Parameters:", svm_grid.best_params_, "with score", svm_grid.best_score_)
print("Best Logistic Regression Parameters:", log_reg_grid.best_params_, "with score", log_reg_grid.best_score_)
print("Best kNN Parameters:", knn_grid.best_params_, "with score", knn_grid.best_score_)
# Out:
# Best SVM Parameters: {'C': 10, 'kernel': 'rbf'} with score 0.9117684698739434
# Best Logistic Regression Parameters: {'C': 0.1} with score 0.731556419345171
# Best kNN Parameters: {'n_neighbors': 3} with score 0.9502319543226777

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Data preparation
metrics = {
    'Model': ['SVM', 'SVM', 'Logistic Regression', 'Logistic Regression', 'kNN', 'kNN'],
    'Class': ['AggressiveStyle', 'EvenPaceStyle', 'AggressiveStyle', 'EvenPaceStyle', 'AggressiveStyle', 'EvenPaceStyle'],
    'Precision': [0.43, 0.98, 0.24, 0.95, 0.59, 0.98],
    'Recall': [0.84, 0.86, 0.73, 0.69, 0.84, 0.92]
}
metrics_df = pd.DataFrame(metrics)

# Plotting Precision and Recall
plt.figure(figsize=(12, 6))

# Precision Plot
plt.subplot(1, 2, 1)
sns.barplot(x='Model', y='Precision', hue='Class', data=metrics_df)
plt.title('Precision by Model and Class')
plt.ylim(0, 1)  # Set the same y-axis limits for comparability

# Recall Plot
plt.subplot(1, 2, 2)
sns.barplot(x='Model', y='Recall', hue='Class', data=metrics_df)
plt.title('Recall by Model and Class')
plt.ylim(0, 1)

plt.tight_layout()
plt.show()

# %%
# Updating the metrics dictionary to include F1-Score and Accuracy
metrics.update({
    'F1-Score': [0.57, 0.91, 0.36, 0.80, 0.69, 0.95],
    'Accuracy': [0.85, 0.85, 0.70, 0.70, 0.91, 0.91]  # Replicate the overall accuracy for both classes for simplicity
})
metrics_df = pd.DataFrame(metrics)

# Plotting F1-Score and Accuracy
plt.figure(figsize=(12, 6))

# F1-Score Plot
plt.subplot(1, 2, 1)
sns.barplot(x='Model', y='F1-Score', hue='Class', data=metrics_df)
plt.title('F1-Score by Model and Class')
plt.ylim(0, 1)

# Accuracy Plot
plt.subplot(1, 2, 2)
# Dropping duplicates since Accuracy is the same for both classes
sns.barplot(x='Model', y='Accuracy', data=metrics_df.drop_duplicates(subset=['Model', 'Accuracy']))
plt.title('Overall Accuracy by Model')
plt.ylim(0, 1)

plt.tight_layout()
plt.show()
